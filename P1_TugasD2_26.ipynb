# %% [markdown]
# <a href="https://colab.research.google.com/github/sileysa/PCVK26_26_SILEYSA/blob/main/P1_TugasD2_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
from typing_extensions import final
import urllib.error

# Membuat list untuk menyimpan url dari beberapa image
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://unair.ac.id/wp-content/uploads/2020/12/Kucing.jpg"
]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)  #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  250  x  375
# <PIL.Image.Image image mode=RGB size=375x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
#Tugas Praktikum D2
#Nomor 1

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
#Tugas Praktikum D2
#Nomor 2

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis menyilang ditengah image
for y in range(tinggi):
    image_3[y, int(y * lebar / tinggi)] = [255, 255, 255]
    image_3[y, int(lebar - 1 - (y * lebar / tinggi))] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
#Tugas Praktikum D2
#Nomor 3

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#menentukan panjang garis
panjang = 100

#menentukan titik awal dan akhir
x_awal = (lebar - panjang) // 3
x_akhir = x_awal + panjang

#membuat garis vertikal ditengah image
for x in range (x_awal, x_akhir):
  image_3[int ((tinggi)/2), x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
#Tugas Praktikum D2
#Nomor 4

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#menentukan koordinat kotak
x1 = 100  #kiri
y1 = 100  #atas
x2 = 200  #kanan
y2 = 200  #bawah

#membuat garis atas dan bawah
for x in range (x1, x2):
  image_3[y1, x] = [255, 255, 255]
  image_3[y2, x] = [255, 255, 255]

#membuat garis kanan dan kiri
for y in range (y1, y2):
  image_3[y, x1] = [255, 255, 255]
  image_3[y, x2] = [255, 255, 255]

#mengisi area kotak dengan warna putih
image_3[y1:y2, x1:x2] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %% [markdown]
# # PERTANYAAN PRAKTIKUM D2
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Collab?
# - Karena Google Collab adalah platform cloud berbasis Jupyter Notebook yang memungkinkan eksekusi kode Python secara interaktif tanpa perlu instalasi lokal. Collab menjadi favorit mahasiswa dan peneliti karena menyediakan akses GPU (Graphics Processing Unit) dan TPU (Tensor Processing Unit) secara gratis, sehingga eksperimen machine learning dan visi komputer dapat dilakukan tanpa perlu perangkat keras mahal.
#
# 2. (A)Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# - NumPy adalah pustaka manipulasi array, yang digunakan untuk mengolah data dalam bentuk array/matriks. Dalam citra digital sendiri dapat direpresentasikan sebagai array pixel.
#
# - Pandas adalah sebuah pustaka untuk mengolah dan memanipulasi data dalam bentuk tabel/dataframe.
# - CV2 digunakan untuk membaca, memproses, mengubah ukuran, melakukan transformasi, dan berbagai operasi computer vision pada citra.
# - Skimage menyediakan fungsi untuk pemrosesan citra seperti filtering, edge detection, dan transformasi morfologi.
# - Matplotlib adalah sebuah pustaka yang menghasilkan gambar dan menyediakan perangkat bantu antarmuka pengguna grafis.
#
# 2. (B)Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# Tidak semua library harus digunakan dalam praktikum sesi ini. Penggunaannya disesuaikan dengan kebutuhan program.
# Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# 3. Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# - Kode tersebut digunakan untuk mengubah ukuran(resize) gambar menjadi setengah dari ukuran yang sebenarnya. “fx=0.5” mengurangi ukuran pada arah horizontal menjadi setengah(50%), “fy=0.5” mengurangi ukuran pada arah vertikal menjadi setengah(50%). Jika kode program tersebut tidak dilakukan maka gambar akan tetap muncul akan tetapi ukuran/resolusi menjadi lebih besar dan membutuhkan lebih banyak ruang pada tampilan karena menggunakan ukuran/resolusi yang sebenarnya.
#
# 4. Perhatikan potongan kode progam berikut :  Apakah kegunaan kode [255,255,255] ? Jelaskan!
# - Kode [255,255,255] merupakan representasi warna putih pada citra RGB, dengan nilai Red(R) maksimum, Green(G) maksimum, dan Blue(B) maksimum maka menghasilkan warna putih. Dalam praktikum, nilai tersebut digunakan untuk membuat garis horizontal berwarna putih di tengah gambar dengan mengubah nilai pixel pada baris tengah gambar.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# - Pixel adalah elemen terkecil penyusun citra digital. Citra digital tersusun dari pixel yang diatur dalam baris dan kolom. Sedangkan resolusi adalah jumlah pixel dalam arah horizontal dan vertikal. Semakin tinggi resolusi, semakin banyak juga pixel yang digunakan sehingga informasi dan detail gambar yang dapat ditampilkan semakin tinggi. Jadi, semakin banyak pixel dalam suatu gambar, semakin tinggi resolusinya dan semakin banyak detail yang dapat ditampilkan. Sebaliknya, resolusi rendah memiliki jumlah pixel lebih sedikit sehingga detail gambar lebih rendah dan gambar dapat terlihat lebih pecah ketika diperbesar.
